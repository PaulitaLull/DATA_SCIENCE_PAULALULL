# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 1
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
frase = '¿Por qué esta magnífica tecnología científica,\n\tque ahorra trabajo y nos hace la vida mas fácil,\n\t\tnos aporta tan poca felicidad?\n\t\t\tLa repuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino. \n "Albert Einstein" '
print(frase)
# Out:
# ¿Por qué esta magnífica tecnología científica,
# 	que ahorra trabajo y nos hace la vida mas fácil,
# 		nos aporta tan poca felicidad?
# 			La repuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.
#  "Albert Einstein"

# %% [markdown]
# ## Ejercicio 2
# 1. Escribe el nombre de la calle de tu domicilio
# 2. Escribe el numero de la calle en otra
# 3. Población en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Crea una quinta variable que concatene todas ellas
# 6. Imprimela por pantalla

# %%
calle="joaquín costa"
numero=" 46"
población=" Valencia"
codigop=" 46005"
frase_total= calle + numero + población + codigop
print(frase_total)
# Out:
# joaquín costa 46 Valencia 46005

# %% [markdown]
# ## Ejercicio 3
# Replica el output del ejercicio dos, pero está vez sin usar una variable intermedia que concatene todas las demas. Realiza este ejercicio en una línea, con un  único `print`

# %%
calle="joaquín costa"
numero=" 46"
población=" Valencia"
codigop=" 46005"
print(calle + numero + población + codigop)
# Out:
# joaquín costa 46 Valencia 46005

# %% [markdown]
# ## Ejercicio 4
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. exec = True
# 6. import = 40
# 7. 81mi_variable = "Agua"
# 8. mi_variable10 = 6

# %% [markdown]
# 1. mi_variable = "Economía
# 2. otra_var = "Ejercicio"
# 3. var_otra = "Ejercicio"
# 4. mi_variab1e = "Alpha"
# 5. exec = True
# 6. import = 40
# 7. mi_variable81 = "Agua"
# 8. mi_variable10 = 6

# %%
mi_variable = "Economía"
otra_var = "Ejercicio"
var_otra = "Ejercicio"
mi_variab1e = "Alpha"
exec = True
importa = 40
mi_variable81 = "Agua"
mi_variable10 = 6

# %% [markdown]
# ## Ejercicio 5
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = (C × 9 / 5) + 32

# %%
grados=input("Dime los grados a convertir:")
f=(int(grados)*9/5)+32
print(f"{grados} grados son {f} farenheit")
# Out:
# 20 grados son 68.0 farenheit

# %% [markdown]
# ## Ejercicio 6
# Comenta en la medida de lo posible el Ejercicio 5. Será suficiente con poner al menos un comentario de línea, y otro multilínea

# %%
'''
En este ejercicio convertimos los grados del usuario a unidades farenheit.
Lo hacemos con un input y una operación básica
'''
# Out:
# '\nEn este ejercicio convertimos los grados del usuario a unidades farenheit.\nLo hacemos con un input y una operación básica\n'
